# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinmichalsmolen/adam/blob/main/MGR6_IMDB_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import Adam
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from sklearn.model_selection import train_test_split

# load dataset
df = pd.read_csv('http://77.55.209.58/IMDB_Dataset.csv')

# preprocessing dataset
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['review'].values)
X = tokenizer.texts_to_sequences(df['review'].values)
X = pad_sequences(X, maxlen=200)
Y = pd.get_dummies(df['sentiment']).values

# split dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# build model architecture
model = Sequential()
model.add(Dense(512, input_shape=(200,), activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(2, activation='softmax'))
print(model.summary())

# compile model using Adam optimizer
adam = Adam(lr=0.0001, decay=1e-5)
model.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# train model
model.fit(X_train, Y_train, batch_size=64, epochs=50, validation_data=(X_test, Y_test), verbose=2)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (2.12.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.2)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow) (67.6.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.53.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.4.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               102912
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 234,754
# Trainable params: 234,754
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 547/547 - 6s - loss: 157.8022 - accuracy: 0.5001 - val_loss: 45.0522 - val_accuracy: 0.5065 - 6s/epoch - 11ms/step
# Epoch 2/50
# 547/547 - 2s - loss: 56.8086 - accuracy: 0.5097 - val_loss: 14.9676 - val_accuracy: 0.5008 - 2s/epoch - 3ms/step
# Epoch 3/50
# 547/547 - 2s - loss: 20.5183 - accuracy: 0.5098 - val_loss: 2.8776 - val_accuracy: 0.5005 - 2s/epoch - 3ms/step
# Epoch 4/50
# 547/547 - 2s - loss: 5.7955 - accuracy: 0.5070 - val_loss: 0.7739 - val_accuracy: 0.4992 - 2s/epoch - 3ms/step
# Epoch 5/50
# 547/547 - 2s - loss: 2.0551 - accuracy: 0.5086 - val_loss: 0.7662 - val_accuracy: 0.4938 - 2s/epoch - 3ms/step
# Epoch 6/50
# 547/547 - 2s - loss: 1.2634 - accuracy: 0.5041 - val_loss: 0.7161 - val_accuracy: 0.5049 - 2s/epoch - 3ms/step
# Epoch 7/50
# 547/547 - 2s - loss: 1.0254 - accuracy: 0.5054 - val_loss: 0.7053 - val_accuracy: 0.5003 - 2s/epoch - 4ms/step
# Epoch 8/50
# 547/547 - 2s - loss: 0.9020 - accuracy: 0.4993 - val_loss: 0.7043 - val_accuracy: 0.4977 - 2s/epoch - 4ms/step
# Epoch 9/50
# 547/547 - 2s - loss: 0.8459 - accuracy: 0.5031 - val_loss: 0.7002 - val_accuracy: 0.4973 - 2s/epoch - 3ms/step
# Epoch 10/50
# 547/547 - 2s - loss: 0.7771 - accuracy: 0.5057 - val_loss: 0.6986 - val_accuracy: 0.5012 - 2s/epoch - 3ms/step
# Epoch 11/50
# 547/547 - 2s - loss: 0.7665 - accuracy: 0.5029 - val_loss: 0.7009 - val_accuracy: 0.4983 - 2s/epoch - 3ms/step
# Epoch 12/50
# 547/547 - 2s - loss: 0.7491 - accuracy: 0.4996 - val_loss: 0.6962 - val_accuracy: 0.4998 - 2s/epoch - 3ms/step
# Epoch 13/50
# 547/547 - 2s - loss: 0.7392 - accuracy: 0.5016 - val_loss: 0.6957 - val_accuracy: 0.4956 - 2s/epoch - 3ms/step
# Epoch 14/50
# 547/547 - 2s - loss: 0.7173 - accuracy: 0.5002 - val_loss: 0.6949 - val_accuracy: 0.4983 - 2s/epoch - 4ms/step
# Epoch 15/50
# 547/547 - 2s - loss: 0.7195 - accuracy: 0.5076 - val_loss: 0.6942 - val_accuracy: 0.4962 - 2s/epoch - 3ms/step
# Epoch 16/50
# 547/547 - 2s - loss: 0.7117 - accuracy: 0.5061 - val_loss: 0.6944 - val_accuracy: 0.4929 - 2s/epoch - 3ms/step
# Epoch 17/50
# 547/547 - 2s - loss: 0.7033 - accuracy: 0.5045 - val_loss: 0.6939 - val_accuracy: 0.4943 - 2s/epoch - 3ms/step
# Epoch 18/50
# 547/547 - 2s - loss: 0.7028 - accuracy: 0.5032 - val_loss: 0.6939 - val_accuracy: 0.4934 - 2s/epoch - 3ms/step
# Epoch 19/50
# 547/547 - 2s - loss: 0.7002 - accuracy: 0.5031 - val_loss: 0.6936 - val_accuracy: 0.4942 - 2s/epoch - 3ms/step
# Epoch 20/50
# 547/547 - 2s - loss: 0.6975 - accuracy: 0.5027 - val_loss: 0.6936 - val_accuracy: 0.4945 - 2s/epoch - 4ms/step
# Epoch 21/50
# 547/547 - 2s - loss: 0.6982 - accuracy: 0.5035 - val_loss: 0.6934 - val_accuracy: 0.4939 - 2s/epoch - 3ms/step
# Epoch 22/50
# 547/547 - 2s - loss: 0.6975 - accuracy: 0.5029 - val_loss: 0.6934 - val_accuracy: 0.4939 - 2s/epoch - 3ms/step
# Epoch 23/50
# 547/547 - 2s - loss: 0.6981 - accuracy: 0.5024 - val_loss: 0.6933 - val_accuracy: 0.4943 - 2s/epoch - 3ms/step
# Epoch 24/50
# 547/547 - 2s - loss: 0.6942 - accuracy: 0.5037 - val_loss: 0.6933 - val_accuracy: 0.4944 - 2s/epoch - 3ms/step
# Epoch 25/50
# 547/547 - 2s - loss: 0.6955 - accuracy: 0.5026 - val_loss: 0.6933 - val_accuracy: 0.4941 - 2s/epoch - 3ms/step
# Epoch 26/50
# 547/547 - 2s - loss: 0.6937 - accuracy: 0.5036 - val_loss: 0.6933 - val_accuracy: 0.4941 - 2s/epoch - 3ms/step
# Epoch 27/50
# 547/547 - 2s - loss: 0.6945 - accuracy: 0.5039 - val_loss: 0.6933 - val_accuracy: 0.4941 - 2s/epoch - 4ms/step
# Epoch 28/50
# 547/547 - 3s - loss: 0.6965 - accuracy: 0.5031 - val_loss: 0.6932 - val_accuracy: 0.4943 - 3s/epoch - 5ms/step
# Epoch 29/50
# 547/547 - 2s - loss: 0.6939 - accuracy: 0.5031 - val_loss: 0.6932 - val_accuracy: 0.4941 - 2s/epoch - 3ms/step
# Epoch 30/50
# 547/547 - 2s - loss: 0.6953 - accuracy: 0.5036 - val_loss: 0.6932 - val_accuracy: 0.4941 - 2s/epoch - 3ms/step
# Epoch 31/50
# 547/547 - 2s - loss: 0.6935 - accuracy: 0.5030 - val_loss: 0.6932 - val_accuracy: 0.4941 - 2s/epoch - 3ms/step
# Epoch 32/50
# 547/547 - 2s - loss: 0.6949 - accuracy: 0.5033 - val_loss: 0.6932 - val_accuracy: 0.4942 - 2s/epoch - 3ms/step
# Epoch 33/50
# 547/547 - 2s - loss: 0.6944 - accuracy: 0.5027 - val_loss: 0.6932 - val_accuracy: 0.4941 - 2s/epoch - 4ms/step
# Epoch 34/50
# 547/547 - 3s - loss: 0.6935 - accuracy: 0.5027 - val_loss: 0.6932 - val_accuracy: 0.4941 - 3s/epoch - 5ms/step
# Epoch 35/50
# 547/547 - 3s - loss: 0.6949 - accuracy: 0.5031 - val_loss: 0.6932 - val_accuracy: 0.4941 - 3s/epoch - 5ms/step
# Epoch 36/50
# 547/547 - 2s - loss: 0.6946 - accuracy: 0.5035 - val_loss: 0.6932 - val_accuracy: 0.4942 - 2s/epoch - 4ms/step
# Epoch 37/50
# 547/547 - 2s - loss: 0.6940 - accuracy: 0.5029 - val_loss: 0.6932 - val_accuracy: 0.4941 - 2s/epoch - 3ms/step
# Epoch 38/50
# 547/547 - 2s - loss: 0.6936 - accuracy: 0.5040 - val_loss: 0.6932 - val_accuracy: 0.4942 - 2s/epoch - 3ms/step
# Epoch 39/50
# 547/547 - 2s - loss: 0.6941 - accuracy: 0.5032 - val_loss: 0.6932 - val_accuracy: 0.4943 - 2s/epoch - 4ms/step
# Epoch 40/50
# 547/547 - 2s - loss: 0.6940 - accuracy: 0.5037 - val_loss: 0.6932 - val_accuracy: 0.4941 - 2s/epoch - 3ms/step
# Epoch 41/50
# 547/547 - 2s - loss: 0.6943 - accuracy: 0.5038 - val_loss: 0.6932 - val_accuracy: 0.4941 - 2s/epoch - 3ms/step
# Epoch 42/50
# 547/547 - 2s - loss: 0.6932 - accuracy: 0.5040 - val_loss: 0.6932 - val_accuracy: 0.4943 - 2s/epoch - 3ms/step
# Epoch 43/50
# 547/547 - 2s - loss: 0.6936 - accuracy: 0.5038 - val_loss: 0.6932 - val_accuracy: 0.4942 - 2s/epoch - 3ms/step
# Epoch 44/50
# 547/547 - 2s - loss: 0.6938 - accuracy: 0.5038 - val_loss: 0.6932 - val_accuracy: 0.4943 - 2s/epoch - 3ms/step
# Epoch 45/50
# 547/547 - 2s - loss: 0.6933 - accuracy: 0.5039 - val_loss: 0.6932 - val_accuracy: 0.4943 - 2s/epoch - 4ms/step
# Epoch 46/50
# 547/547 - 2s - loss: 0.6939 - accuracy: 0.5046 - val_loss: 0.6932 - val_accuracy: 0.4943 - 2s/epoch - 4ms/step
# Epoch 47/50
# 547/547 - 2s - loss: 0.6964 - accuracy: 0.5036 - val_loss: 0.6932 - val_accuracy: 0.4943 - 2s/epoch - 3ms/step
# Epoch 48/50
# 547/547 - 2s - loss: 0.6936 - accuracy: 0.5039 - val_loss: 0.6932 - val_accuracy: 0.4946 - 2s/epoch - 3ms/step
# Epoch 49/50
# 547/547 - 2s - loss: 0.6934 - accuracy: 0.5047 - val_loss: 0.6931 - val_accuracy: 0.4947 - 2s/epoch - 3ms/step
# Epoch 50/50
# 547/547 - 2s - loss: 0.6930 - accuracy: 0.5043 - val_loss: 0.6932 - val_accuracy: 0.4945 - 2s/epoch - 3ms/step
